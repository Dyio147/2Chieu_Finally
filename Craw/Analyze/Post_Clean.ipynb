# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\xps\\Documents\\sv nam 2\\IAI\\Craw\\HaiChieu.csv')
df.head()
# Out:
#            post_id                                               text  \
# 0  944802137004100                        Cuốn quá hong dứt ra được 🫢
# 1  944225883728392  eIm mới hai tuổi, mà suốt ngày dính phờ-ốt, tó...
# 2  943155540502093  Trong cuốn sách “Khám phá đứa trẻ bên trong bạ...
# 3  942979587186355  Khi nào thì nhà không còn là nơi để trở về?\nK...
# 4  942643393886641  Dưới đó là dòng người, là mặt đường hay là cái...
#
#                                            post_text shared_text  \
# 0                        Cuốn quá hong dứt ra được 🫢         NaN
# 1  eIm mới hai tuổi, mà suốt ngày dính phờ-ốt, tó...         NaN
# 2  Trong cuốn sách “Khám phá đứa trẻ bên trong bạ...         NaN
# 3  Khi nào thì nhà không còn là nơi để trở về?\nK...         NaN
# 4  Dưới đó là dòng người, là mặt đường hay là cái...         NaN
#
#    original_text                 time   timestamp  \
# 0            NaN  2023-11-28 11:12:18  1701169938
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        150 non-null    int64
#  1   text                           149 non-null    object
#  2   post_text                      148 non-null    object
#  3   shared_text                    4 non-null      object
#  4   original_text                  0 non-null      float64
#  5   time                           150 non-null    object
#  6   timestamp                      150 non-null    int64
#  7   image                          122 non-null    object
#  8   image_lowquality               149 non-null    object
#  9   images                         150 non-null    object
#  10  images_description             150 non-null    object
#  11  images_lowquality              150 non-null    object
# ...

# %%
# Chọn các cột cần giữ lại
selected_columns = [
    "post_id",
    "text",
    "post_text",
    "time",
    "image",
    "video",
    "comments",
    "shares",
    "comments_full",
    "reactors",
    "reactions",
    "reaction_count"
]

# Tạo DataFrame mới từ các cột đã chọn
df_clean = df[selected_columns]

# %%
df_clean
# Out:
#               post_id                                               text  \
# 0     944802137004100                        Cuốn quá hong dứt ra được 🫢
# 1     944225883728392  eIm mới hai tuổi, mà suốt ngày dính phờ-ốt, tó...
# 2     943155540502093  Trong cuốn sách “Khám phá đứa trẻ bên trong bạ...
# 3     942979587186355  Khi nào thì nhà không còn là nơi để trở về?\nK...
# 4     942643393886641  Dưới đó là dòng người, là mặt đường hay là cái...
# ..                ...                                                ...
# 145  1284488945821254  Dù mọi người có nói ước mơ của chúng ta thật t...
# 146  1283287759274706  Đôi khi "Là Chính Mình" và "Được Yêu Quý" là 2...
# 147  1283238102613005  Chỉ khi nào bản thân biết cách tự chữa lành, t...
# 148  1282719682664847     Tề Minh Huấn‎Hai Chiều\n25 tháng 3 lúc 23:00 ·
# 149  1281280769475405  Trong mỗi người luôn có sẵn những mầm cây tốt ...
#
#                                              post_text                 time  \
# ...

# %%
df_clean['post_text'] = df_clean['post_text'].fillna('')

# Thay thế giá trị NaN bằng 0
df_clean['image'] = df_clean['image'].fillna(0)

# Thay thế giá trị khác NaN bằng 1
df_clean['image'] = (df_clean['image'] != 0).astype(int)

# Thay thế giá trị NaN bằng 0
df_clean['video'] = df_clean['video'].fillna(0)

# Thay thế giá trị khác NaN bằng 1
df_clean['video'] = (df_clean['video'] != 0).astype(int)
# Out:
# C:\Users\xps\AppData\Local\Temp\ipykernel_2180\1958879262.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['post_text'] = df_clean['post_text'].fillna('')
# C:\Users\xps\AppData\Local\Temp\ipykernel_2180\1958879262.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['image'] = df_clean['image'].fillna(0)
# C:\Users\xps\AppData\Local\Temp\ipykernel_2180\1958879262.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   post_id         150 non-null    int64
#  1   text            150 non-null    object
#  2   post_text       150 non-null    object
#  3   time            150 non-null    object
#  4   image           150 non-null    int32
#  5   video           150 non-null    int32
#  6   comments        150 non-null    int64
#  7   shares          150 non-null    int64
#  8   comments_full   150 non-null    object
#  9   reactions       150 non-null    object
#  10  reaction_count  150 non-null    int64
# dtypes: int32(2), int64(4), object(5)
# memory usage: 11.8+ KB

# %%
df_clean
# Out:
#               post_id                                               text  \
# 0     944802137004100                        Cuốn quá hong dứt ra được 🫢
# 1     944225883728392  eIm mới hai tuổi, mà suốt ngày dính phờ-ốt, tó...
# 2     943155540502093  Trong cuốn sách “Khám phá đứa trẻ bên trong bạ...
# 3     942979587186355  Khi nào thì nhà không còn là nơi để trở về?\nK...
# 4     942643393886641  Dưới đó là dòng người, là mặt đường hay là cái...
# ..                ...                                                ...
# 145  1284488945821254  Dù mọi người có nói ước mơ của chúng ta thật t...
# 146  1283287759274706  Đôi khi "Là Chính Mình" và "Được Yêu Quý" là 2...
# 147  1283238102613005  Chỉ khi nào bản thân biết cách tự chữa lành, t...
# 148  1282719682664847     Tề Minh Huấn‎Hai Chiều\n25 tháng 3 lúc 23:00 ·
# 149  1281280769475405  Trong mỗi người luôn có sẵn những mầm cây tốt ...
#
#                                              post_text                 time  \
# ...

# %%
# Lưu DataFrame vào file CSV
df_clean.to_csv("HaiChieu_clean.csv", index=False)
